# %%
x = 5
y = 5
result = x == y
print(f"{x} is equal to {y}: {result}")
# Out:
# 5 is equal to 5: True

# %%
a = 10
b = 7
result = a != b
print(f"{a} is not equal to {b}: {result}")
# Out:
# 10 is not equal to 7: True

# %%
r = 20
s = 20
result = r >= s
print(f"{r} is greater than or equal to {s}: {result}")
# Out:
# 20 is greater than or equal to 20: True

# %%
k = 30
l = 35
result = k <= l
print(f"{k} is less than or equal to {l}: {result}")
# Out:
# 30 is less than or equal to 35: True
