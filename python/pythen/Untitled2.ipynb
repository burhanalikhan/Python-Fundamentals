# %%
class Basket:
    def __init__(self):
        self.location=""
        self.oranges=[]
    def add_orange(self,orange):
        self.oranges.append(orange)
        print("orange is added")
    def discard(self):
        if not self.oranges:
            return none
        else:
            self.oranges.pop()
            print("oranges discard")

class Orange:
    def __init__(self,weight=0.0,orchard="",date="",basket=""):
        self.weight=weight
        self.orchard=orchard
        self.date=date
        self.basket=basket
    def pick(self,basket):
        print(f"{self.basket} is picked")
    def squeeze(self):
        print(f"Amount of Juice is {self.weight*0.5}")
b1=Basket()
b1.add_orange(1)
# Out:
# orange is added

# %%
o1=Orange(4.5,"bb","1234","b1")

# %%
o1.squeeze()
# Out:
# Amount of Juice is 2.25

# %%
o1.pick(b1)
# Out:
# b1 is picked

# %%
b1.oranges
# Out:
# [1]

# %%
b1.discard()
# Out:
# oranges discard
