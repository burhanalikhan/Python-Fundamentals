# %%
class basket:
    def __init__(self):
        self.location=""
        self.oranges=[]
    def add_orange(self,orange):
        self.oranges.append(orange)
        print("orange is added")
    def discard(self):
        if not oranges:
            return none
        else:
            self.oranges.pop()
            print("oranges discard")

class orange:
    def __init__(self,weight=0.0,orchard="",date=""):
        self.weight=weight
        self.orchard=orchard
        self.date=date
    def pick(self):
        print(f"{basket} is picked")
    def squeeze(self):
        print(f"Amount of Juice is {self.weight*0.5}")
b1=basket()
b1.add_orange(2)
# Out:
# orange is added

# %%
b1.oranges
# Out:
# [2]

# %%
o1=orange(4.5,"bbb","kara")
o1.pick()
# Out:
# <class '__main__.basket'> is picked

# %%
fruits = ['apple', 'banana', 'cherry']
removed_fruit = fruits.pop()
print(fruits)  # Output: ['apple', 'cherry']
print("Removed fruit:", removed_fruit)  # Output: Removed fruit: banana
# Out:
# ['apple', 'banana']
# Removed fruit: cherry
