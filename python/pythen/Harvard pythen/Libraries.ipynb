# %%
from random import choice
def main():
    x=choice(["heads","tails"])
    print(f"x is {x}")
main()
# Out:
# x is heads

# %%
import random

x=random.randint(1,10)
print(x)
# Out:
# tails

# %%
import random
x=["a","b","c","d"]
random.shuffle(x)

for y in x:
    print(y)
# Out:
# a
# c
# b
# d

# %%
import statistics
print(statistics.mean([100,90,89]))
# Out:
# 93

# %%
import sys
if len(sys.argv)<2:
    sys.exit("Too few Arguments")
elif len(sys.argv)>2:
    sys.exit("Too many Arguments")

print(f"My name is {sys.argv[3]}")
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Too many Arguments

# %%
names=["Burhan","Farhan","Saifullah","khan","orhan"]
for name in names[1]:
    print(f"Hello {name}")
# Out:
# Hello F
# Hello a
# Hello r
# Hello h
# Hello a
# Hello n

# %%
import cowsay
x=input("What is your name? ")
cowsay.trex("hello "+x)
# Out:
# What is your name? Burhan
#   ____________
# | hello Burhan |
#   ============
#                    \
#                     \
#                      \
#                       \
#                          .-=-==--==--.
#                    ..-=="  ,'o`)      `.
#                  ,'         `"'         \
#                 :  (                     `.__...._
#                 |                  )    /         `-=-.
#                 :       ,vv.-._   /    /               `---==-._
#                  \/\/\/VV ^ d88`;'    /                         `.
#                      ``  ^/d88P!'    /             ,              `._
#                         ^/    !'   ,.      ,      /                  "-,,__,,--'""""-.
#                        ^/    !'  ,'  \ . .(      (         _           )  ) ) ) ))_,-.\
#                       ^(__ ,!',"'   ;:+.:%:a.     \:.. . ,'          )  )  ) ) ,"'    '
#                       ',,,'','     /o:::":%:%a.    \:.:.:         .    )  ) _,'
#                        """'       ;':::'' `+%%%a._  \%:%|         ;.). _,-""
#                               ,-='_.-'      ``:%::)  )%:|        /:._,"
#                              (/(/"           ," ,'_,'%%%:       (_,'
#                                             (  (//(`.___;        \
#                                              \     \    `         `
#                                               `.    `.   `.        :
#                                                 \. . .\    : . . . :
#                                                  \. . .:    `.. . .:
#                                                   `..:.:\     \:...\
#                                                    ;:.:.;      ::...:
#                                                    ):%::       :::::;
#                                                __,::%:(        :::::
#                                             ,;:%%%%%%%:        ;:%::
#                                               ;,--""-.`\  ,=--':%:%:\
#                                              /"       "| /-".:%%%%%%%\
#                                                              ;,-"'`)%%)
#                                                             /"      "|

# %%
from saying import hello
hello("burhan")
# Out:
# hello burhan
